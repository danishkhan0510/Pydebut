# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
data = pd.read_csv("/content/CardioGoodFitness-1.csv")

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
data.describe(include='all')
# Out:
#        Product         Age Gender  ...     Fitness         Income       Miles
# count      180  180.000000    180  ...  180.000000     180.000000  180.000000
# unique       3         NaN      2  ...         NaN            NaN         NaN
# top      TM195         NaN   Male  ...         NaN            NaN         NaN
# freq        80         NaN    104  ...         NaN            NaN         NaN
# mean       NaN   28.788889    NaN  ...    3.311111   53719.577778  103.194444
# std        NaN    6.943498    NaN  ...    0.958869   16506.684226   51.863605
# min        NaN   18.000000    NaN  ...    1.000000   29562.000000   21.000000
# 25%        NaN   24.000000    NaN  ...    3.000000   44058.750000   66.000000
# 50%        NaN   26.000000    NaN  ...    3.000000   50596.500000   94.000000
# 75%        NaN   33.000000    NaN  ...    4.000000   58668.000000  114.750000
# max        NaN   50.000000    NaN  ...    5.000000  104581.000000  360.000000
#
# [11 rows x 9 columns]

# %%
data.info()
#there are no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
data.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f32dba5c910>,
# ...
#       dtype=object)

# %%
sns.boxplot(data['Gender'],data['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pd.crosstab(data['Gender'],data['Product'])
# Out:
# Product  TM195  TM498  TM798
# Gender
# Female      40     29      7
# Male        40     31     33

# %%
pd.crosstab(data['Product'],data['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
sns.countplot(data['Product'],hue=data['Gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pd.pivot_table(data=data,index=['Product','Gender'],columns=['MaritalStatus'],aggfunc='count')
# Out:
#                      Age        Education  ...  Miles     Usage
# MaritalStatus  Partnered Single Partnered  ... Single Partnered Single
# Product Gender                             ...
# TM195   Female        27     13        27  ...     13        27     13
#         Male          21     19        21  ...     19        21     19
# TM498   Female        15     14        15  ...     14        15     14
#         Male          21     10        21  ...     10        21     10
# TM798   Female         4      3         4  ...      3         4      3
#         Male          19     14        19  ...     14        19     14
#
# [6 rows x 12 columns]

# %%
pd.pivot_table(data,'Income',index=['Product','Gender'],columns=['MaritalStatus'],aggfunc='mean')
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
pd.pivot_table(data,'Miles',index=['Product','Gender'],columns=['MaritalStatus'],aggfunc='mean')
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
sns.pairplot(data)

# %%
print(data.std())
print(data.mean())
# Out:
# Age              6.943498
# Education        1.617055
# Usage            1.084797
# Fitness          0.958869
# Income       16506.684226
# Miles           51.863605
# dtype: float64
# Age             28.788889
# Education       15.572222
# Usage            3.455556
# Fitness          3.311111
# Income       53719.577778
# Miles          103.194444
# dtype: float64

# %%
sns.distplot(data['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.hist(by='Gender',column='Age')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f32cbd099d0>,
# ...
#       dtype=object)

# %%
data.hist(by='Gender',column='Income')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f32cbc8d8d0>,
# ...
#       dtype=object)

# %%
data.hist(by='Gender',column='Miles')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f32cbb4b090>,
# ...
#       dtype=object)

# %%
corr=data.corr()
sns.heatmap(corr,annot=True)

# %%
from sklearn import linear_model

# %%
regression = linear_model.LinearRegression()

# %%
y = data['Miles']
x = data[['Usage','Fitness']]

# %%
regression.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regression.intercept_
# Out:
# -56.74288178464862

# %%
regression.coef_
# Out:
# array([20.21486334, 27.20649954])
